# %%
include("zad 10-8.jl")
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
f(x) = (25x^2 + 1)^(-1)
w1 = Werner_Lagrange(9, f, -1, 1)
@printf("max error: %e\n", max_error(f, w1, -1, 1))

x = linspace(-1,1, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0, label="f(x)")
y = w1.(x)
plot!(x, y, color="green", label="Lagrange")
# Out:
# max error: 3.002940e-01
# <img src="data:image/png;base64,..." />

# %%
w2 = Werner_Lagrange(9, f, -1, 1, ch_nodes(10, -1, 1))
@printf("max error: %e\n", max_error(f, w2, -1, 1))

x = linspace(-1,1, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0, label="f(x)")
y = w2.(x)
plot!(x, y, color="green", label="Lagrange")
# Out:
# max error: 2.691783e-01
# <img src="data:image/png;base64,..." />

# %%
w3 = Werner_Lagrange(9, f, -1, 1, che_nodes(9, -1, 1))
@printf("max error: %e\n", max_error(f, w3, -1, 1))

x = linspace(-1,1, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0, label="f(x)")
y = w2.(x)
plot!(x, y, color="green", label="Lagrange")
# Out:
# max error: 3.190953e-01
# <img src="data:image/png;base64,..." />

# %%
o1 = find_optimal(1, f, Legendre_Poly(1), -1, 1)
@printf("max error: %e\n", max_error(f, o1, -1, 1))

x = linspace(-1,1, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0, label="f(x)")
y = o1.(x)
plot!(x, y, color="green", label="Lagrange")
# Out:
# MethodError: no method matching getindex(::#Legendre_Poly, ::Int64)
#
# Stacktrace:
#  [1] (::#optimal#123{Int64,#f,#Legendre_Poly,Int64,Int64})(::Float64) at /home/lukas/Documents/Uni/Analiza Matematyczna/Other/zad 10-8.jl:98
#  [2] max_error(::#f, ::#optimal#123{Int64,#f,#Legendre_Poly,Int64,Int64}, ::Int64, ::Int64) at /home/lukas/Documents/Uni/Analiza Matematyczna/Other/zad 10-8.jl:35
#  [3] include_string(::String, ::String) at ./loading.jl:522

# %%
P0 = Poly([1], "x")
P1 = Poly([0,1], "x")
# Out:
# Poly(x)

# %%
Legendre_Poly(1)(10)
# Out:
# 10

# %%
find_optimal(9, f, Legendre_Poly, -1, 1)
# Out:
# (::optimal) (generic function with 1 method)
