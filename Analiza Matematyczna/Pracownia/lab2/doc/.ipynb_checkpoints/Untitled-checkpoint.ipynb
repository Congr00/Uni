# %%
include("../prog/program.jl")
# Out:
# max_error (generic function with 1 method)

# %%
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
using Plots
pyplot()
#ylabel("test")
#xlabel("test")
f(x) = (1 + 25*(x^2))^(-1)
a = -1; b = 1; n = 70
p1 = Lagrange(n, f, a, b)
p2 = Baricentric_Lagrange(n, f, a, b)
p3 = Werner_Lagrange(n, f, a, b)
ch1 = Lagrange(n, f, a, b, ch_nodes(n, a, b))
ch2 = Baricentric_Lagrange(n, f, a, b, ch_nodes(n, a, b))
rd1 = Lagrange(n, f, a, b, rd_nodes(n, a, b))
rd2 = Baricentric_Lagrange(n, f, a, b, rd_nodes(n, a, b))

x = linspace(a,b, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0, label="f(x)")
y = p1.(x)
plot(x, y, color="green", label="L(x)")
y = p2.(x)
plot(x, y, color="blue", label="B(x)")
y = p3.(x)
plot(x, y, color="orange", label="W(x)")
@printf("lagrange max error: %f\n", max_error(f, p1, a, b))
@printf("bericentric max error: %f\n", max_error(f, p2, a, b))
@printf("Werner max error: %f\n", max_error(f, p3, a, b))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf69dc0d0>)
# lagrange max error: 8655373026.989141
# bericentric max error: 7562074983.816834
# Werner max error: 374391.039522

# %%
x = linspace(-0.8,0.8, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0)
y = rd1.(x)
plot(x, y, color="green")
y = rd2.(x)
plot(x, y, color="blue")
@printf("lagrange max error: %f\n", max_error(f, rd1, a, b))
@printf("bericentric max error: %f\n", max_error(f, rd2, a, b))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf70c5d90>)
# lagrange max error: 0.458318
# bericentric max error: 113.029101

# %%
x = linspace(-1,1, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0)
y = ch1.(x)
plot(x, y, color="green")
y = ch2.(x)
plot(x, y, color="blue")
@printf("lagrange max error: %f\n", max_error(f, ch1, a, b))
@printf("bericentric max error: %f\n", max_error(f, ch2, a, b))
println(ch_nodes(n, a, b))
println(ch_nodes2(n, a, b))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf7886f50>)
# lagrange max error: 0.108929
# bericentric max error: 0.108929
# [0.989821, 0.909632, 0.75575, 0.540641, 0.281733, 2.83277e-16, -0.281733, -0.540641, -0.75575, -0.909632, -0.989821]
# [0.989821, 0.909632, 0.75575, 0.540641, 0.281733, 6.12323e-17, -0.281733, -0.540641, -0.75575, -0.909632, -0.989821]

# %%
f(x) = atan(x)
a = -1; b = 1; n = 10
p1 = Lagrange(n, f, a, b)
p2 = Baricentric_Lagrange(n, f, a,b)
ch1 = Lagrange(n, f, a, b, ch_nodes(n, a, b))
ch2 = Baricentric_Lagrange(n, f, a, b, ch_nodes(n, a, b))
rd1 = Lagrange(n, f, a, b, rd_nodes(n, a, b))
rd2 = Baricentric_Lagrange(n, f, a, b, rd_nodes(n, a, b))

x = linspace(a,b, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0, label="f(x)")
y = p1.(x)
plot(x, y, color="green", label="L(x)")
y = p2.(x)
plot(x, y, color="blue", label="B(x)")
@printf("lagrange max error: %f\n", max_error(f, p1, a, b))
@printf("bericentric max error: %f\n", max_error(f, p2, a, b))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf7608fd0>)
# lagrange max error: 0.000107
# bericentric max error: 0.000107

# %%
x = linspace(-0.8,0.8, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0)
y = rd1.(x)
plot(x, y, color="green")
y = rd2.(x)
plot(x, y, color="blue")
@printf("lagrange max error: %f\n", max_error(f, rd1, a, b))
@printf("bericentric max error: %f\n", max_error(f, rd2, a, b))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf74a60d0>)
# lagrange max error: 0.004356
# bericentric max error: 0.027651

# %%
x = linspace(-1,1, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0)
y = ch1.(x)
plot(x, y, color="green")
y = ch2.(x)
plot(x, y, color="blue")
@printf("lagrange max error: %f\n", max_error(f, ch1, a, b))
@printf("bericentric max error: %f\n", max_error(f, ch2, a, b))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf742cb90>)
# lagrange max error: 0.000015
# bericentric max error: 0.000015

# %%
f(x) = maximum([0.0, 1-4x])
a = -5; b = 5; n = 10
p1 = Lagrange(n, f, a, b)
p2 = Baricentric_Lagrange(n, f, a,b)
ch1 = Lagrange(n, f, a, b, ch_nodes(n, a, b))
ch2 = Baricentric_Lagrange(n, f, a, b, ch_nodes(n, a, b))
rd1 = Lagrange(n, f, a, b, rd_nodes(n, a, b))
rd2 = Baricentric_Lagrange(n, f, a, b, rd_nodes(n, a, b))

x = linspace(a,b, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0, label="f(x)")
y = p1.(x)
plot(x, y, color="green", label="L(x)")
y = p2.(x)
plot(x, y, color="blue", label="B(x)")
@printf("lagrange max error: %f\n", max_error(f, p1, a, b))
@printf("bericentric max error: %f\n", max_error(f, p2, a, b))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf722b310>)
# lagrange max error: 3.915349
# bericentric max error: 3.915349

# %%
x = linspace(-2.5,2.5, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0)
y = rd1.(x)
plot(x, y, color="green")
y = rd2.(x)
plot(x, y, color="blue")
@printf("lagrange max error: %f\n", max_error(f, rd1, a, b))
@printf("bericentric max error: %f\n", max_error(f, rd2, a, b))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf7e027d0>)
# lagrange max error: 6197.429195
# bericentric max error: 43.329057

# %%
x = linspace(-5,5, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0)
y = ch1.(x)
plot(x, y, color="green")
y = ch2.(x)
plot(x, y, color="blue")
@printf("lagrange max error: %f\n", max_error(f, ch1, a, b))
@printf("bericentric max error: %f\n", max_error(f, ch2, a, b))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf72802d0>)
# lagrange max error: 0.475348
# bericentric max error: 0.475348

# %%
f(x) = abs(x)
a = -1; b = 1; n = 10
p1 = Lagrange(n, f, a, b)
p2 = Baricentric_Lagrange(n, f, a,b)
ch1 = Lagrange(n, f, a, b, ch_nodes(n, a, b))
ch2 = Baricentric_Lagrange(n, f, a, b, ch_nodes(n, a, b))


x = linspace(a,b, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0, label="f(x)")
y = p1.(x)
plot(x, y, color="green", label="L(x)")
y = p2.(x)
plot(x, y, color="blue", label="B(x)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf746f650>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcf843cd90>

# %%
x = linspace(-1,1, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0)
y = ch1.(x)
plot(x, y, color="green")
y = ch2.(x)
plot(x, y, color="blue")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf79edf50>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcf78bdd50>

# %%
x = linspace(a,b, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0, label="f(x)")
y = p1.(x)
plot(x, y, color="green", label="L(x)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf7874590>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcf7843c50>

# %%
x = linspace(a,b, 100); y = f.(x)
plot(x, y, color="red", linewidth=2.0, label="f(x)")
y = p2.(x)
plot(x, y, color="blue", label="L(x)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcf79df550>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcf77c8b90>
